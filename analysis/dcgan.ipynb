# %%
# %matplotlib notebook
from IPython.display import Image

# %%
model = 'nz8_ortho1.00e-01_d1.00e+00_epoch60'
PATH = '/u/xl/tjlane/cryoem/dynanet/particle_simulations/ortho/kdef/models/%s/' % model

# %%
Image(filename=PATH + 'training_curves.png')

# %%
Image(filename=PATH + 'real_v_fake.png')

# %%
Image(filename=PATH + 'latent/dz_6.png')
